# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from scipy.stats import mode
# %matplotlib inline

# %%
pd.set_option('display.max_columns', 500)

df = pd.read_csv('SongCSV.csv')
df.head()
# Out:
#    SongNumber                 SongID  AlbumID  \
# 0           1  b'SOMZWCG12A8C13C480'   300848
# 1           2  b'SOCIWDW12A8C13D406'   300822
# 2           3  b'SOXVLOJ12AB0189215'   514953
# 3           4  b'SONHOTT12A8C13493C'   287650
# 4           5  b'SOFSOCN12A8C143F5D'   611336
#
#                                 AlbumName               ArtistID  \
# 0                          b'Fear Itself'  b'ARD7TVE1187B99BFB1'
# 1                           b'Dimensions'  b'ARMJAGH1187FB546F3'
# 2  b'Las Numero 1 De La Sonora Santanera'  b'ARKRRTF1187B9984DA'
# 3                        b'Friend Or Foe'  b'AR7G5I41187FB4CE6C'
# 4                        b'Muertos Vivos'  b'ARXR32B1187FB57099'
#
#    ArtistLatitude      ArtistLocation  ArtistLongitude           ArtistName  \
# 0             NaN  b'California - LA'              NaN            b'Casual'
# 1        35.14968       b'Memphis TN'        -90.04892      b'The Box Tops'
# ...

# %%
# # reformat = ['SongID','AlbumName','ArtistID','ArtistLocation','ArtistLongitude','ArtistName','Title','TrackID']
# reformat = ['SongID','AlbumName','ArtistLongitude','ArtistName','Title','TrackID']


# for col in reformat:
#     reformatted_col = []
#     for ele in df[col]:
# #         print(ele)
#         reformatted_val = ele[2:-1]
#         print(reformatted_val)
#         if len(reformatted_val) > 0:
#             reformatted_col.append(reformatted_col)
#         else:
#             reformatted_col.append(None)
#     df[col] = reformatted_col

# df.head()
